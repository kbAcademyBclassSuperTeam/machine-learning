# %%
import numpy as np
import itertools
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
#!pip install librosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install librosa
# import librosa
# audio_path = './data/위급상황/원천데이터/sample/7.응급의료_420186_label.wav'
# y, sr = librosa.load(audio_path)

# %%
audio_np = np.array(y, np.float32)

# %%
audio_np.shape
# Out:
# (70781,)

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=20)  
plt.figure(figsize=(18, 5))
plt.plot(audio_np)
plt.ylim((-0.05, 0.05))
plt.show()

# %%
import IPython.display as ipd

ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# - wav는 매 순간의 음압을 측정하여 그 수치를 저장한 형태이기 때문에 그 자체로 음악을 분석하기에 적합하지 않음 (음의 높이와 세기를 듣는것이지 순간의 음압을 듣는게 아니기 때문)
# - 푸리에 변환과 같은 변환 기법을 이용하여 시간 축의 데이터를 주파수 축의 데이터로 바꿔줘야할 필요가 있음
# - 푸리에 변환 대신 푸리에 변환과 유사한 Constant-Q 변환을 사용
# - Constant-Q 변환은 주파수 축이 로그 단위로 변환되고, 각 주파수에 따라 해상도가 다양하게 처리되기 때문에(저주파는 저해상도, 고주파는 고해상도) 음악을 처리하는 데에 푸리에 변환보다 유리
# - 주파수 대역을 저장할 리스트 audio_cqt 선언
# - constant-Q 변환할 때는 변환할 오디오 데이터와 sampling rate가 필요
# - 해당 데이터에서는 sampling rate가 모두 동일하므로 따로 처리가 필요하지 않음
# - 여기서는 Constant-Q 변환을 사용해 오디오 데이터를 주파수 대역으로 변환
# - 변환에는 앞서 준비한 데이터를 가져와 사용하며, Constant-Q 변환에는 librosa.cqt 함수를 사용
# - 여기서 n_bins는 옥타브 단계 및 개수를, bins_per_octave는 한 옥타브가 가지는 단계를 의미
# - 라벨에 대해선 원 핫 인코딩을 적용

# %%
import librosa.display
ret = librosa.cqt(y, sr, hop_length=1024, n_bins=24*7, bins_per_octave=24)
ret = np.abs(ret)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_29792/317595949.py:2: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   ret = librosa.cqt(y, sr, hop_length=1024, n_bins=24*7, bins_per_octave=24)

# %%
amp_db = librosa.amplitude_to_db(np.abs(ret),ref=np.max)
librosa.display.specshow(amp_db, sr=sr, x_axis='time', y_axis='cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: Frequency axis exceeds Nyquist. Did you remember to set all spectrogram parameters in specshow?
#   return f(*args, **kwargs)

# %%
amp_db
# Out:
# array([[-80.      , -80.      , -80.      , ..., -78.35343 , -78.228966,
#         -78.4387  ],
#        [-77.91558 , -77.60909 , -77.55693 , ..., -77.82179 , -77.73484 ,
#         -78.0055  ],
#        [-76.98161 , -76.923325, -77.28448 , ..., -77.9745  , -78.381035,
#         -79.11892 ],
#        ...,
#        [-80.      , -80.      , -80.      , ..., -80.      , -80.      ,
#         -80.      ],
#        [-80.      , -80.      , -80.      , ..., -80.      , -80.      ,
#         -80.      ],
#        [-78.52332 , -80.      , -80.      , ..., -80.      , -80.      ,
#         -80.      ]], dtype=float32)

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=80)
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel',sr=sr, fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')
# Out:
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]

# %%
S_dB.shape
# Out:
# (80, 139)

# %%
s = np.array(S_dB, np.float32)
s.shape
# Out:
# (80, 139)

# %%
def get_target_data(data_dir):
    audio_path_list = []
    audio_path_list.extend(glob(os.path.join(data_dir,'*.wav')))
    label_list = [1] * len(audio_path_list)
           
    return audio_path_list, label_list

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import os
from glob import glob
all_audio_path, all_label = get_target_data('./원천데이터/sample')

# %%
len(all_audio_path), len(all_label)
# Out:
# (1073, 1073)

# %%
all_audio_path
# Out:
# ['./data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_105095_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_109734_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_112116_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_121567_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_128474_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_132358_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_133045_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_133763_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_134587_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_136487_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_137508_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_137863_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_138969_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_140332_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_140886_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_141332_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_142190_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_142306_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_142530_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_143449_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_143680_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_147629_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_147764_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148378_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148406_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148448_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148475_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148518_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148531_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_148545_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_18590_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_23770_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_27595_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_29631_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_32552_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652422_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652431_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652434_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652437_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652441_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652451_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652455_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652465_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652481_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652503_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652524_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652529_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652553_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652571_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652583_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652597_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652599_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652607_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652614_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652624_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652636_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652642_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652657_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652667_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652673_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652678_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652688_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652779_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652800_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652808_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652814_label.wav',
#  './data/위급상황/원천데이터/sample\\1.강제추행(성범죄)_652824_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1259962_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1259972_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1259981_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1259986_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1259993_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260001_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260013_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260020_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260025_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260041_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260049_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260068_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260075_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1260091_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_1261833_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_317476_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_317895_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_317959_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_318233_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_318628_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_318944_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_319150_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_322611_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_322789_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_322934_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_452349_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_452472_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_452570_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_452718_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_452796_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_457655_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_457896_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_458008_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_458233_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_458430_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_466574_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_466614_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_466710_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_466842_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_466993_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_467079_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_467221_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_467927_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_468041_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_468289_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_468562_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_468728_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_469099_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_469535_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_469579_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_469793_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_469896_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_470113_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_473011_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_475245_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_475716_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_475869_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_475893_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_475945_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_476014_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_476279_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_541954_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_541977_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_542629_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_542663_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_542678_label.wav',
#  './data/위급상황/원천데이터/sample\\11.낙상_542696_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_1082496_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_3488_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_3510_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_450124_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_450416_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_450554_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_455475_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_455515_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_455613_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_455748_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_455925_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_456051_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_456140_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_456218_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_456459_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_456830_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_457061_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_457080_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_457221_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_457245_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_457308_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_457718_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_517596_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_517616_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_517777_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_517896_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_859384_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_859440_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_859710_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_860825_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_860919_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_861111_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_862407_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_862431_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_862504_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_862616_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863096_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863099_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863161_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863275_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863370_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863683_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_863731_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_864221_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_864400_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_865630_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_865678_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_865806_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_870587_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_870670_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_870707_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_870879_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_870958_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_870970_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_871313_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_871327_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_871331_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_871469_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_871492_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_872217_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_924680_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_924744_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_925105_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_925204_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_925230_label.wav',
#  './data/위급상황/원천데이터/sample\\12.붕괴사고_925285_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_262949_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_263858_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_265776_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_265927_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266067_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266180_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266417_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266538_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266615_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266809_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266856_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266901_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_266934_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267003_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267072_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267149_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267258_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267325_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267328_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267366_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267398_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267423_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267630_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍_267904_label.wav',
#  './data/위급상황/원천데이터/sample\\14.태풍-강풍
label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_465167_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_465255_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_465304_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_465663_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_466415_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_567130_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_567284_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_567381_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_666693_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_668669_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_669572_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_669652_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_671420_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_671935_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_672209_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_672541_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_672599_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_672716_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673096_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673134_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673168_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673234_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673251_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673274_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673295_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673316_label.wav',
#  './data/위급상황/원천데이터/sample\\6.갇힘_673339_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_349583_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_360793_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_420186_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_434444_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_434574_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_568568_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_568641_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_569545_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_569881_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_569922_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570026_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570411_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570436_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570483_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570511_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570546_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570559_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570579_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570612_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570629_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_570645_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572015_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572045_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572147_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572182_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572191_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572203_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572216_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572434_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572448_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572459_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572485_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572493_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572508_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572521_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572533_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572658_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572788_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572800_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572808_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_572908_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_573035_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_573047_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_573313_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_573337_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_573491_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_573532_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_831242_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926358_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926366_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926379_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926409_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926423_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926452_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926461_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926498_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926512_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926544_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926561_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926569_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926582_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926592_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926608_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926617_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926623_label.wav',
#  './data/위급상황/원천데이터/sample\\7.응급의료_926631_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_120518_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_120562_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_120680_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_120714_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_120843_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_120877_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_206862_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_206918_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_206985_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_207030_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_220902_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_222188_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_222205_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_222220_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_227244_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_245532_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_245546_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_245549_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_245558_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_245562_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_245566_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_49438_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_49605_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_49637_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_49726_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_553063_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554290_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554405_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554468_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554519_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554582_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554612_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554639_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554662_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554717_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554789_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_554802_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_555029_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_555058_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_555066_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556339_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556441_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556703_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556785_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556807_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556821_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556836_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556844_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556855_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_556862_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558971_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558979_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558981_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558983_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558991_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558996_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_558997_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_559003_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_559008_label.wav',
#  './data/위급상황/원천데이터/sample\\8.전기사고_559009_label.wav',
#  ...]

# %%
def get_normal_data(data_dir):
    normal_path_list = []
    
    for case_name in os.listdir(data_dir):
        current_path = os.path.join(data_dir, case_name)
        for case_name_2 in os.listdir(current_path):
            current_path_2 = os.path.join(current_path, case_name_2)
            for case_name_3 in os.listdir(current_path_2):
                current_path_3 = os.path.join(current_path_2, case_name_3)
                normal_path_list.extend(glob(os.path.join(current_path_3,'*.wav')))
    
    label_list = [0] * len(normal_path_list)
           
    return normal_path_list, label_list

# %%
all_normal_path, all_normal_label = get_normal_data('./원천데이터/KrespSpeech')

# %%
len(all_normal_path), len(all_normal_label)
# Out:
# (5463, 5463)

# %% [markdown]
# ## 경로를 이용해서 모든 데이터 가져온 후 음성데이터에서
#
# 주요 개념
#
# 1. 푸리에 변환
#
# 음성 신호에 푸리에 변환을 적용하면 각 진동수 성분이 그 음성에 얼마나 들어있는지 알 수 있습니다.
#
# 쉽게 설명하면 음성 신호에 저음이 얼마나 있고, 고음이 얼마나 있는지를 정량적으로 구할 수 있습니다.
#
# 2. STFT(Short Time Fourier Transform)
#
# 음성을 작게(0.01초 수준) 잘라서 각 작은 조각에 푸리에 변환을 적용할 수 있습니다.
# 이것을 STFT라고 부르고 일반적으로 이 결과의 L2 norm을 Spectrogram이라고 부릅니다.
#
# 3. Melspectrogram
#
# Melspectrogram은 Spectrogram에 mel-filter라는 필터를 적용해서 얻어집니다. 이는 사람의 청각 기관이 저음에서 주파
# 수 변화에 민감하고 고음에서는 주파수의 변화에 덜 민감한 특징을 반영하고 있습니다.
#
# - Function and Option
#
# torchaudio에서는 다음과 같이 Spectrogram과 Melspectrogram을 얻을 수 있는 프로세스를 정의할 수 있습니다.
# AmplitudeToDB는 power단위의 Spectrogram 또는 Melspectrogram을 dB(로그) 단위로 변환해 줍니다.
#
# 1. win_length
#
# 음성을 작은 조각으로 자를 때 작은 조각의 크기를 의미합니다.
# 자연어 처리 분야에서는 25ms의 크기를 기본으로 하고 있으며 16000Hz인 음성에서는 400에 해당하는 값입니다. (16000/40)
# 22050Hz의 파일이기 때문에 552로 설정하겠습니다. (22050/40, 소수점 올림)
#
# 2. n_fft
#
# win_length의 크기로 잘린 음성의 작은 조각은 0으로 Padding 되어서 n_fft로 크기가 맞춰집니다. 그렇게 padding 된 조각
# 에 푸리에 변환이 적용됩니다. 따라서 n_fft는 win_length보다 크거나 같아야 하고 일반적으로 속도를 위해서 값으로 설정
# 합니다.
# win_length의 크기가 552이기 때문에 512는 될 수 없고, 1024는 너무 크다고 생각하여 win_length와 똑같이 552로 설정하
# 겠습니다.
#
# 3. hop_length
#
# 음성을 작은 조각으로 자를 때, 자르는 간격을 의미합니다. 즉, 이 길이만큼 옆으로 밀면서 작은 조각을 얻습니다.
# 일반 적으로 10ms의 크기를 기본으로 하고 있으며 16000Hz인 음성에서는 160에 해당하는 값입니다. (16000/100)
# 22050Hz의 파일이기 때문에 221로 설정하겠습니다. (22050/100)
#
# 4. n_mels
#
# 적용할 mel filter의 개수를 의미합니다
#
# n_mel이 80이면 Melspectrogram의 주파수 방향 성분 수는 80인 것입니다.
#
#
# 마지막으로 Spectrogram과 Melspectrogram의 해상력에 대해 설명하겠습니다.
#
# win_length가 커질수록 주파수 성분에 대한 해상력은 높아지지만(정밀해진다) 시간 성분에 대한 해상력은 낮아지게 됩니다.
#
# 즉, 더 정밀한 주파수 분포를 얻을 수 있으나 시간에 따른 주파수 변화를 관찰하기가 어려워집니다.
#
# 반대로 win_length가 작은 경우에는 주파수 성분에 대한 해상력은 낮아지지만, 시간 성분에 대한 해상력은 높아지게 됩니다.
#
# 따라서 적절한 값을 찾는 것이 중요합니다.
#
# 또한 n_fft를 키우는 경우 주파수 성분의 수는 증가할지 몰라도 실제 주파수의 해상력은 증가하지 않습니다

# %% [markdown]
# '마지막으로 spectrogram과 melspectrogram의 해상력에 대해 설명하겠습니다. win_length가 커질수록 주파수 성분에 대한 해상력은 높아지지만, 즉 더 정밀해지지만, 시간 성분에 대한 해상력은 낮아지게 됩니다. 즉, 더 정밀한 주파수 분포를 얻을 수 있으나 시간에 따른 주파수 변화를 관찰하기가 어려워집니다. 반대로 win_length가 작은 경우에는 주파수 성분에 대한 해상력은 낮아지지만, 시간 성분에 대한 해상력은 높아지게 됩니다. 따라서 적절한 값을 찾는 것이 중요합니다.'

# %%
import pandas as pd

df = []
df_log = []
target = []

# %%
for path in all_audio_path:
    y, sr = librosa.load(path)
    n_fft = int(np.ceil(0.025*sr))
    win_length = int(np.ceil(0.025*sr))
    hop_length = int(np.ceil(0.01*sr))
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=40, win_length=win_length, hop_length=hop_length, n_fft=n_fft)

    df.append(S)
    target.append(1)

# %%
for path in all_normal_path:
    y, sr = librosa.load(path)
    n_fft = int(np.ceil(0.025*sr))
    win_length = int(np.ceil(0.025*sr))
    hop_length = int(np.ceil(0.01*sr))
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=40, win_length=win_length, hop_length=hop_length, n_fft=n_fft)

    df.append(S)
    target.append(0)

# %%
arr_df = []
arr_target = []
import itertools

for i in range(len(df)):
    if df[i].shape[0] * df[i].shape[1] < 15000:
        arr_df.append( list(itertools.chain(*df[i]))) 
        arr_target.append(target[i])

# %%
max_len = max(len(item) for item in arr_df)
print('최대 길이 :',max_len)
# Out:
# 최대 길이 : 14960

# %%
for sentence in arr_df:
    avg = sum(sentence)/len(sentence)
    while len(sentence) < max_len:
        sentence.append(avg)

padded_np = np.array(arr_df)
padded_np
# Out:
# array([[5.07052903e-07, 5.24821417e-07, 1.01279431e-06, ...,
#         6.16056212e-01, 6.16056212e-01, 6.16056212e-01],
#        [1.21625308e-04, 2.69443291e-04, 8.10075071e-05, ...,
#         1.12162697e+00, 1.12162697e+00, 1.12162697e+00],
#        [5.18962054e-07, 1.58216562e-06, 5.63662638e-07, ...,
#         2.83458889e-01, 2.83458889e-01, 2.83458889e-01],
#        ...,
#        [1.08399481e-05, 9.08469883e-06, 2.62070853e-06, ...,
#         8.28350709e-02, 8.28350709e-02, 8.28350709e-02],
#        [1.30315730e-05, 4.06591607e-06, 1.04848086e-05, ...,
#         5.31588647e-02, 5.31588647e-02, 5.31588647e-02],
#        [6.82509608e-06, 1.12158932e-06, 7.52377559e-07, ...,
#         8.11740282e-02, 8.11740282e-02, 8.11740282e-02]])

# %%
padded_np.shape
# Out:
# (3974, 14960)

# %%
target_np = np.array(arr_target)
target_np.shape
# Out:
# (3974,)

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# scaler.fit(padded_np)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    padded_np,
    target_np,
    test_size=0.2,
    random_state=0
)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
pred = DT.predict(X_test)
acc = accuracy_score(pred, y_test)
print(acc)
# Out:
# 0.8735119047619048

# %% [markdown]
# # CNN 으로 돌리기

# %%
padded_np.shape
# Out:
# (3974, 14960)

# %%
b = padded_np.reshape(3974, 40, 374)
b.shape
# Out:
# (3974, 40, 374)

# %%
re_np = np.expand_dims(b, -1)
re_np.shape
# Out:
# (3974, 40, 374, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    re_np,
    target_np,
    test_size=0.2,
    random_state=0
)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from keras.layers import Conv2D, MaxPool2D, Flatten

def model_CNN_build():
    model = Sequential()
    input = Input(shape=(40,374,1))

    output = Conv2D(64, 3, strides=1, padding='same', activation='relu')(input)
    output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)

    output = Conv2D(128, 3, strides=1, padding='same', activation='relu')(input)
    output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)
    
    output = Conv2D(256, 3, strides=1, padding='same', activation='relu')(output)
    output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)
    
    output = Conv2D(512, 3, strides=1, padding='same', activation='relu')(output)
    output = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(output)
    
    output=Flatten()(output)
    output=Dense(512, activation='relu')(output)
    output=Dense(256, activation='relu')(output)
    output=Dense(128, activation='relu')(output)
    output=Dense(64, activation='relu')(output)
    output=Dense(1, activation='sigmoid')(output)
    
    model = Model(inputs=[input], outputs=output)
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

    return model

# %%
model = model_CNN_build()
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 40, 374, 1)]      0
#
#  conv2d_16 (Conv2D)          (None, 40, 374, 128)      1280
#
#  max_pooling2d_16 (MaxPoolin  (None, 20, 187, 128)     0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 20, 187, 256)      295168
#
#  max_pooling2d_17 (MaxPoolin  (None, 10, 94, 256)      0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 10, 94, 512)       1180160
#
#  max_pooling2d_18 (MaxPoolin  (None, 5, 47, 512)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 120320)            0
#
#  dense_19 (Dense)            (None, 512)               61604352
#
#  dense_20 (Dense)            (None, 256)               131328
#
#  dense_21 (Dense)            (None, 128)               32896
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dense_23 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 63,253,505
# Trainable params: 63,253,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('CNN_second_model2.h5', monitor='acc', mode='max', verbose=1, save_best_only=True)


hist = model.fit(X_train, y_train, epochs=20, verbose=0, callbacks=[es,mc], batch_size=128, validation_split=0.2)
# Out:
# Epoch 1: acc improved from -inf to 0.79984, saving model to CNN_second_model2.h5
#
# Epoch 2: acc improved from 0.79984 to 0.89776, saving model to CNN_second_model2.h5
#
# Epoch 3: acc improved from 0.89776 to 0.93158, saving model to CNN_second_model2.h5
#
# Epoch 4: acc improved from 0.93158 to 0.94770, saving model to CNN_second_model2.h5
#
# Epoch 5: acc improved from 0.94770 to 0.96186, saving model to CNN_second_model2.h5
#
# Epoch 6: acc did not improve from 0.96186
#
# Epoch 7: acc improved from 0.96186 to 0.97365, saving model to CNN_second_model2.h5
#
# Epoch 8: acc improved from 0.97365 to 0.97955, saving model to CNN_second_model2.h5
#
# Epoch 9: acc improved from 0.97955 to 0.98388, saving model to CNN_second_model2.h5
#
# Epoch 10: acc did not improve from 0.98388
#
# Epoch 11: acc did not improve from 0.98388
#
# Epoch 12: acc improved from 0.98388 to 0.99017, saving model to CNN_second_model2.h5
#
# Epoch 13: acc did not improve from 0.99017
#
# Epoch 14: acc did not improve from 0.99017
#
# Epoch 15: acc did not improve from 0.99017
#
# Epoch 16: acc improved from 0.99017 to 0.99096, saving model to CNN_second_model2.h5
#
# Epoch 17: acc improved from 0.99096 to 0.99214, saving model to CNN_second_model2.h5
#
# Epoch 18: acc did not improve from 0.99214
#
# Epoch 19: acc did not improve from 0.99214
#
# Epoch 20: acc improved from 0.99214 to 0.99371, saving model to CNN_second_model2.h5

# %%
model.evaluate(X_test,y_test)
# Out:
# 25/25 [==============================] - 32s 1s/step - loss: 0.5513 - acc: 0.9170
# [0.5513036251068115, 0.9169811606407166]

# %%
pred = model.predict(X_test)

pred = pred.round()
pred = pred.flatten() # 1차원으로 변경

from sklearn.metrics import recall_score, precision_score

recall_score(y_test,pred), precision_score(y_test,pred)
# Out:
# (0.7218543046357616, 0.8195488721804511)
